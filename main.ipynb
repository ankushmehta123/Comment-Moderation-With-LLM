# %%
import pandas as pd
from dotenv import load_dotenv
from groq import Groq
import json
import time
import re

# %%
# Load .env with GROQ_API_KEY
load_dotenv()

# Initialize Groq client
groq = Groq()

# %%
# LLM Classification Function
def classify_comment_with_llm(comment_text):
    prompt = f'''
You are a content moderation assistant.

Analyze the following user comment and respond in JSON format with:
- is_offensive: true/false
- offense_type: one of ["hate speech", "harassment", "profanity", "toxicity", "none"]
- explanation: a short explanation of why it was or wasn't offensive.

Comment: """{comment_text}"""

Respond ONLY with JSON:
{{
  "is_offensive": true/false,
  "offense_type": "one of above",
  "explanation": "..."
}}
'''

    try:
        chat_completion = groq.chat.completions.create(
            messages=[{"role": "user", "content": prompt}],
            model="deepseek-r1-distill-llama-70b",
            temperature=0.3
        )

        content = chat_completion.choices[0].message.content.strip()
        json_str = re.search(r'\{.*\}', content, flags=re.DOTALL).group(0)
        result = json.loads(json_str)

    except Exception as e:
        result = {
            "is_offensive": False,
            "offense_type": "none",
            "explanation": f"Error or malformed response: {str(e)}"
        }

    return result

# %%
# Load comments CSV
input_file = "comments.csv"  # <-- Your input file here
df = pd.read_csv(input_file).head(100)
df['comment_text'] = df['comment_text'].fillna("")

results = []
for i, row in df.iterrows():
    print(f"Analyzing comment {i+1}/{len(df)}...")
    result = classify_comment_with_llm(row['comment_text'])
    results.append(result)
    time.sleep(1)  # Prevent rate limiting

# Add AI-generated fields to DataFrame
df['is_offensive'] = [r['is_offensive'] for r in results]
df['offense_type'] = [r['offense_type'] for r in results]
df['explanation'] = [r['explanation'] for r in results]
# Out:
# Analyzing comment 1/100...
# Analyzing comment 2/100...
# Analyzing comment 3/100...
# Analyzing comment 4/100...
# Analyzing comment 5/100...
# Analyzing comment 6/100...
# Analyzing comment 7/100...
# Analyzing comment 8/100...
# Analyzing comment 9/100...
# Analyzing comment 10/100...
# Analyzing comment 11/100...
# Analyzing comment 12/100...
# Analyzing comment 13/100...
# Analyzing comment 14/100...
# Analyzing comment 15/100...
# Analyzing comment 16/100...
# Analyzing comment 17/100...
# Analyzing comment 18/100...
# Analyzing comment 19/100...
# Analyzing comment 20/100...
# Analyzing comment 21/100...
# Analyzing comment 22/100...
# Analyzing comment 23/100...
# Analyzing comment 24/100...
# Analyzing comment 25/100...
# Analyzing comment 26/100...
# Analyzing comment 27/100...
# Analyzing comment 28/100...
# Analyzing comment 29/100...
# Analyzing comment 30/100...
# Analyzing comment 31/100...
# Analyzing comment 32/100...
# Analyzing comment 33/100...
# Analyzing comment 34/100...
# Analyzing comment 35/100...
# Analyzing comment 36/100...
# Analyzing comment 37/100...
# Analyzing comment 38/100...
# Analyzing comment 39/100...
# Analyzing comment 40/100...
# Analyzing comment 41/100...
# Analyzing comment 42/100...
# Analyzing comment 43/100...
# Analyzing comment 44/100...
# Analyzing comment 45/100...
# Analyzing comment 46/100...
# Analyzing comment 47/100...
# Analyzing comment 48/100...
# Analyzing comment 49/100...
# Analyzing comment 50/100...
# Analyzing comment 51/100...
# Analyzing comment 52/100...
# Analyzing comment 53/100...
# Analyzing comment 54/100...
# Analyzing comment 55/100...
# Analyzing comment 56/100...
# Analyzing comment 57/100...
# Analyzing comment 58/100...
# Analyzing comment 59/100...
# Analyzing comment 60/100...
# Analyzing comment 61/100...
# Analyzing comment 62/100...
# Analyzing comment 63/100...
# Analyzing comment 64/100...
# Analyzing comment 65/100...
# Analyzing comment 66/100...
# Analyzing comment 67/100...
# Analyzing comment 68/100...
# Analyzing comment 69/100...
# Analyzing comment 70/100...
# Analyzing comment 71/100...
# Analyzing comment 72/100...
# Analyzing comment 73/100...
# Analyzing comment 74/100...
# Analyzing comment 75/100...
# Analyzing comment 76/100...
# Analyzing comment 77/100...
# Analyzing comment 78/100...
# Analyzing comment 79/100...
# Analyzing comment 80/100...
# Analyzing comment 81/100...
# Analyzing comment 82/100...
# Analyzing comment 83/100...
# Analyzing comment 84/100...
# Analyzing comment 85/100...
# Analyzing comment 86/100...
# Analyzing comment 87/100...
# Analyzing comment 88/100...
# Analyzing comment 89/100...
# Analyzing comment 90/100...
# Analyzing comment 91/100...
# Analyzing comment 92/100...
# Analyzing comment 93/100...
# Analyzing comment 94/100...
# Analyzing comment 95/100...
# Analyzing comment 96/100...
# Analyzing comment 97/100...
# Analyzing comment 98/100...
# Analyzing comment 99/100...
# Analyzing comment 100/100...

# %%
# output_file = "output_file.csv"
# df.to_csv(output_file, index=False)

# %%
import pandas as pd
df = pd.read_csv("comments.csv")

# %%
df = df.head(1000)

# %%
df.to_csv("comments.csv", index=False)
